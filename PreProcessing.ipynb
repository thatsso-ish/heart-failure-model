# %%
import pandas as pd

# %%
pddf = pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
pddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
pdDF = pddf.copy()
pdDF
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
pdDF.equals(pddf)
# Out:
# True

# %%
pdDF = pdDF.drop_duplicates(keep = False)
pdDF
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
def remove_whitespace(s):
    return s.strip()
pdDF = pdDF.applymap(lambda x: remove_whitespace(x) if isinstance(x, str) else x)
pdDF
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
pdDF.drop(['anaemia', 'DEATH_EVENT'], axis=1, inplace=True)
pdDF
# Out:
#       age  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0                       582         0                 20
# 1    55.0                      7861         0                 38
# 2    65.0                       146         0                 20
# 3    50.0                       111         0                 20
# 4    65.0                       160         1                 20
# ..    ...                       ...       ...                ...
# 294  62.0                        61         1                 38
# 295  55.0                      1820         0                 38
# 296  45.0                      2060         1                 60
# 297  45.0                      2413         0                 38
# 298  50.0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# ...

# %%
pdDF= pdDF.dropna()

# %%
pdDF.shape
# Out:
# (299, 11)

# %%
pdDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 298
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   creatinine_phosphokinase  299 non-null    int64
#  2   diabetes                  299 non-null    int64
#  3   ejection_fraction         299 non-null    int64
#  4   high_blood_pressure       299 non-null    int64
#  5   platelets                 299 non-null    float64
#  6   serum_creatinine          299 non-null    float64
#  7   serum_sodium              299 non-null    int64
#  8   sex                       299 non-null    int64
#  9   smoking                   299 non-null    int64
#  10  time                      299 non-null    int64
# dtypes: float64(3), int64(8)
# memory usage: 28.0 KB

# %%
pdDF['age'] = pd.to_numeric(pdDF['age'], errors='coerce').fillna(0).astype(int)
pdDF['platelets'] = pd.to_numeric(pdDF['platelets'], errors='coerce').fillna(0).astype(int)
pdDF['serum_creatinine'] = pd.to_numeric(pdDF['serum_creatinine'], errors='coerce').fillna(0).astype(int)

# %%
pdDF.describe()
# Out:
#               age  creatinine_phosphokinase    diabetes  ejection_fraction  \
# count  299.000000                299.000000  299.000000         299.000000
# mean    60.829431                581.839465    0.418060          38.083612
# std     11.894997                970.287881    0.494067          11.834841
# min     40.000000                 23.000000    0.000000          14.000000
# 25%     51.000000                116.500000    0.000000          30.000000
# 50%     60.000000                250.000000    0.000000          38.000000
# 75%     70.000000                582.000000    1.000000          45.000000
# max     95.000000               7861.000000    1.000000          80.000000
#
#        high_blood_pressure      platelets  serum_creatinine  serum_sodium  \
# count           299.000000     299.000000        299.000000    299.000000
# mean              0.351171  263358.026756          0.979933    136.625418
# ...

# %%
pd.get_dummies(pdDF)
# Out:
#      age  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     75                       582         0                 20
# 1     55                      7861         0                 38
# 2     65                       146         0                 20
# 3     50                       111         0                 20
# 4     65                       160         1                 20
# ..   ...                       ...       ...                ...
# 294   62                        61         1                 38
# 295   55                      1820         0                 38
# 296   45                      2060         1                 60
# 297   45                      2413         0                 38
# 298   50                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1     265000                 1           130    1
# ...

# %%
pdDF.equals(pddf)
# Out:
# False

# %%
pdDF.to_csv('NewHeartFailure.csv', index = False)

# %% [markdown]
# LinkedIn
# Ismael (Ishmael T.) Ngobeni
